# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/amah67/mlintern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing to create a machine learning system that helps detect fraud. Fraud detection is a clear, high-stakes decision process due to the fact that it has an immediate business impact. Fraud prevention and user experience can be balanced by going beyond basic static criteria and recognizing complex patterns in transaction behaviour.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision - Which incoming, high-risk security payment is coming through that the system should freeze for the manual review?
#
# Who acts on it - Fraud analysts and security operation teams who inspect flagged accounts, contact cardholders or process chargebacks.
#
# Cost of a wrong call - A wrong call could result in stolen money, chargeback fees and a negative reputation. It could also lead to valuable time of the security team being wasted.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")

# Load the dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Display basic information about the dataset
print("\n--- Data Summary from 'content_refresh_anonymized.csv' ---")
total_records = len(df)
print(f"Dataset scale: {total_records:,} total records (e.g., content entries).")

# Check for 'search_volume' and 'competition' columns before calculating averages
if 'search_volume' in df.columns:
    avg_search_volume = df['search_volume'].mean()
    print(f"Average 'search_volume': {avg_search_volume:,.2f}")
else:
    print("'search_volume' column not found.")

if 'competition' in df.columns:
    avg_competition = df['competition'].mean()
    print(f"Average 'competition' (0-1 scale): {avg_competition:,.2f}")
else:
    print("'competition' column not found.")

# Inform about the missing 'is_fraud' column
if 'is_fraud' not in df.columns:
    print("\n--- Important Note for Fraud Detection Lane ---")
    print("The column 'is_fraud' (or a similar fraud indicator) was not found in this dataset ('content_refresh_anonymized.csv').")
    print("This dataset appears to be related to content performance (e.g., search volume, competition).")
    print("To proceed with your 'fraud detection' lane, please clarify:")
    print("1. Is there another column in this dataset that represents fraud, or")
    print("2. Should we use a different dataset that contains fraud-related information?")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.
#
# --- Data Summary from 'content_refresh_anonymized.csv' ---
# Dataset scale: 30,000 total records (e.g., content entries).
# Average 'search_volume': 158.88
# Average 'competition' (0-1 scale): 0.15
#
# --- Important Note for Fraud Detection Lane ---
# The column 'is_fraud' (or a similar fraud indicator) was not found in this dataset ('content_refresh_anonymized.csv').
# This dataset appears to be related to content performance (e.g., search volume, competition).
# To proceed with your 'fraud detection' lane, please clarify:
# 1. Is there another column in this dataset that represents fraud, or
# 2. Should we use a different dataset that contains fraud-related information?

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim - This approach offers decision-making guidance and prioritisation based on risk to assist humans in focusing on risky transactions. Claims will only pertain to correlations identified between the features of transactions and the labels of fraud.
#
# What I cannot claim - I will not be able to provide a causation ("such and such feature causes fraud") or a hundred percent fraud prevention system ("100% fraud-proof system"). My proposed model is only a recommendation of what needs to be checked first, but does not replace human discretion.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
